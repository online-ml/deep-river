# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
data_dir = Path('./IncrementalDL/tracks/data_sources/dynamic features/2010-11.txt')
data = pd.read_csv(str(data_dir),
                   sep=' ',
                   lineterminator='\n',
                   header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/9v/6vgjjd891x95vm1dqct37y5r0000gn/T/ipykernel_26163/3444828548.py in <module>
#       1 data_dir = Path('./IncrementalDL/tracks/data_sources/dynamic features/2010-11.txt')
# ----> 2 data = pd.read_csv(str(data_dir), sep=' ', lineterminator='\n', header=None)
#       3
#
# ~/Documents/environments/IncrementalDL/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.describe()
# Out:
#                                                         0
# count                                                3620
# unique                                               3181
# top     0.719298245614 5:1 8:1 19:4 22:2 24:14 34:30 3...
# freq                                                   27

# %%
path = Path('./IncrementalDL/tracks/data_sources/mobile_activity/X_train.txt')
X = pd.read_csv(str(path), delimiter=' ', header=None, error_bad_lines=False)
# Out:
# /Users/kulbach/Documents/environments/IncrementalDL/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
X.head(5)
# Out:
#                                                    0
# 0    2.8858451e-001 -2.0294171e-002 -1.3290514e-0...
# 1    2.7841883e-001 -1.6410568e-002 -1.2352019e-0...
# 2    2.7965306e-001 -1.9467156e-002 -1.1346169e-0...
# 3    2.7917394e-001 -2.6200646e-002 -1.2328257e-0...
# 4    2.7662877e-001 -1.6569655e-002 -1.1536185e-0...

# %%
path = Path('./IncrementalDL/tracks/data_sources/household/household_power_consumption.txt')
X = pd.read_csv(str(path),delimiter=';', low_memory=False)

# %%
X['Time'][0].split(':')

X['Time'].str.split(':', 2, expand=True)
# Out:
#           0   1   2
# 0        17  24  00
# 1        17  25  00
# 2        17  26  00
# 3        17  27  00
# 4        17  28  00
# ...      ..  ..  ..
# 2075254  20  58  00
# 2075255  20  59  00
# 2075256  21  00  00
# 2075257  21  01  00
# 2075258  21  02  00
#
# [2075259 rows x 3 columns]

# %%
X.columns
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                 0.000
# 2075255  26/11/2010  20:59:00               0.944                 0.000
# 2075256  26/11/2010  21:00:00               0.938                 0.000
# 2075257  26/11/2010  21:01:00               0.934                 0.000
# 2075258  26/11/2010  21:02:00               0.932                 0.000
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...
